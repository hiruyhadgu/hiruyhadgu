# %%
import pandas as pd
import os

# %%
data_file_folder = './'
df = []

for file in os.listdir(data_file_folder):
    if file.endswith('.xlsx'):
        sheet_name, extension = file.split('.')
        df.append(pd.read_excel(file, sheet_name = sheet_name, usecols = 'A:J'))
df_master = pd.concat(df, axis=0)

# %%
df_master.head()
# Out:
#       Receiving Committee Filing Period Contribution Date  \
# 0  Jones, Opel Friends of   2022 Annual        2021-06-10
# 1  Jones, Opel Friends of   2022 Annual        2021-03-15
# 2  Jones, Opel Friends of   2022 Annual        2021-03-24
# 3  Jones, Opel Friends of   2022 Annual        2021-06-10
# 4  Jones, Opel Friends of   2022 Annual        2021-03-23
#
#                            Contributor Name  \
# 0  Annapolis Junction Apartments Homes, LLC
# 1                           Bradley, Vaughn
# 2                              Lewis, Anton
# 3                          Talkin & Oh, LLP
# 4                             Harvey, Bruce
#
#                                Contributor Address  \
# 0                 PO Box 30946, Bethesda, MD 20824
# 1            6288 Bright Plume, Columbia, MD 21044
# 2   104 Garden Gate Lane, Upper Marlboro, MD 20774
# 3  5100 Dorsey Hall Drive, Ellicott City, MD 21042
# 4              7792 Elmwood Road, Fulton, MD 20759
#
#               Contributor Type Contribution Type  Contribution Amount  \
# 0  Business/Group/Organization             Check               1000.0
# 1                   Individual       Credit Card                100.0
# 2                   Individual       Credit Card                250.0
# 3  Business/Group/Organization             Check               1000.0
# 4                   Individual       Credit Card                250.0
#
#               Employer Name            Employer Occupation
# 0                       NaN                            NaN
# 1            Vaughn Bradley                          Legal
# 2                       GSK            Sales and Marketing
# 3                       NaN                            NaN
# 4  Williamsburg Group L.L.C  Administrative and Management

# %%
candidate_name = df_master['Receiving Committee'].unique().tolist()
donor_name = df_master['Contributor Name'].unique().tolist()
contributions = df_master['Contribution Amount'].unique().tolist()
filing_period = df_master['Filing Period'].unique().tolist()

# %%
mask=df_master['Receiving Committee'].isin(candidate_name)
## mask2 = df_master['Contributor Name'].isin(donor_name)

# %%
df_contribution_sum = df_master[mask].groupby(by = ['Contributor Name', 'Receiving Committee']).sum()[['Contribution Amount']]
df_contribution_count = df_master[mask].groupby(by = ['Contributor Name','Receiving Committee']).count()[['Contribution Amount']]
df_contribution_count = df_contribution_count.rename(columns = {'Contribution Amount':'No of Contributions'})

# %%
df_grouped = [df_contribution_sum, df_contribution_count]

# %%
df_grouped = pd.concat(df_grouped, axis = 1)
df_grouped = df_grouped.sort_values(by=['No of Contributions'], ascending = False)

# %%
df_grouped
# Out:
#                                                        Contribution Amount  \
# Contributor Name            Receiving Committee
# Henry Oakcrum, Ora          Jones, Opel Friends of                 1645.18
# Wagner, Joseph              Kurtom, Neveen Friends of              5638.10
# Taylor, John                Jones, Opel Friends of                  265.00
# Jacobson, Jonas             Jones, Opel Friends of                 2250.00
# Jafri, Deeba                Jones, Opel Friends of                  370.18
# ...                                                                    ...
# Harris, Marcus Citizens for Jones, Opel Friends of                  700.00
# Hamlin, Derrick             Jones, Opel Friends of                  100.00
# Guyton, Jamila              Jones, Opel Friends of                   20.18
# Gutschick, Carl             Kurtom, Neveen Friends of               200.00
# waters, wardell             Jones, Opel Friends of                  750.00
#
#                                                        No of Contributions
# Contributor Name            Receiving Committee
# Henry Oakcrum, Ora          Jones, Opel Friends of                      17
# Wagner, Joseph              Kurtom, Neveen Friends of                   13
# Taylor, John                Jones, Opel Friends of                       9
# Jacobson, Jonas             Jones, Opel Friends of                       5
# Jafri, Deeba                Jones, Opel Friends of                       5
# ...                                                                    ...
# Harris, Marcus Citizens for Jones, Opel Friends of                       1
# Hamlin, Derrick             Jones, Opel Friends of                       1
# Guyton, Jamila              Jones, Opel Friends of                       1
# Gutschick, Carl             Kurtom, Neveen Friends of                    1
# waters, wardell             Jones, Opel Friends of                       1
#
# [347 rows x 2 columns]

# %%
df_grouped
# Out:
#                                                        Contribution Amount  \
# Contributor Name            Receiving Committee
# Henry Oakcrum, Ora          Jones, Opel Friends of                 1645.18
# Wagner, Joseph              Kurtom, Neveen Friends of              5638.10
# Taylor, John                Jones, Opel Friends of                  265.00
# Jacobson, Jonas             Jones, Opel Friends of                 2250.00
# Jafri, Deeba                Jones, Opel Friends of                  370.18
# ...                                                                    ...
# Harris, Marcus Citizens for Jones, Opel Friends of                  700.00
# Hamlin, Derrick             Jones, Opel Friends of                  100.00
# Guyton, Jamila              Jones, Opel Friends of                   20.18
# Gutschick, Carl             Kurtom, Neveen Friends of               200.00
# waters, wardell             Jones, Opel Friends of                  750.00
#
#                                                        No of Contributions
# Contributor Name            Receiving Committee
# Henry Oakcrum, Ora          Jones, Opel Friends of                      17
# Wagner, Joseph              Kurtom, Neveen Friends of                   13
# Taylor, John                Jones, Opel Friends of                       9
# Jacobson, Jonas             Jones, Opel Friends of                       5
# Jafri, Deeba                Jones, Opel Friends of                       5
# ...                                                                    ...
# Harris, Marcus Citizens for Jones, Opel Friends of                       1
# Hamlin, Derrick             Jones, Opel Friends of                       1
# Guyton, Jamila              Jones, Opel Friends of                       1
# Gutschick, Carl             Kurtom, Neveen Friends of                    1
# waters, wardell             Jones, Opel Friends of                       1
#
# [347 rows x 2 columns]
